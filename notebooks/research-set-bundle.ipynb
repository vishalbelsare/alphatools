# %%
#import alphatools.research
from alphatools.research import (
    get_pricing,
    set_bundle
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c254fbc539da> in <module>()
#       1 #import alphatools.research
# ----> 2 from alphatools.research import (
#       3     get_pricing,
#       4     set_bundle
#       5 )
#
# ImportError: No module named alphatools.research

# %%
df = get_pricing(['AAPL', 'MSFT'], '2001-01-04', '2017-12-29')

df.plot();

set_bundle('sharadar-funds')

df = get_pricing(['SPY'], '2018-01-04', '2020-03-20')

df.plot()
