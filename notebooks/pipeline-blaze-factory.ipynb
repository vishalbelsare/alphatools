# %%
from alphatools.research import run_pipeline, get_symbols
from alphatools.data import Factory
import pandas as pd
from zipline.pipeline import Pipeline
from zipline.pipeline.data import USEquityPricing
from zipline.pipeline.filters import StaticAssets
from zipline.pipeline.factors import CustomFactor
# Out:
# /home/ubuntu/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/odo/backends/pandas.py:94: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2974f7b1e780> in <module>
# ----> 1 from alphatools.research import run_pipeline, get_symbols
#       2 from alphatools.data import Factory
#       3 import pandas as pd
#       4 from zipline.pipeline import Pipeline
#       5 from zipline.pipeline.data import USEquityPricing
#
# ~/hca/alphatools/alphatools/research/__init__.py in <module>
# ----> 1 from .research import (
#       2     loaders,
#       3     blaze_loader,
#       4     run_pipeline,
#       5     get_pricing,
#
# ~/hca/alphatools/alphatools/research/research.py in <module>
#       9 from zipline.utils.calendars import get_calendar
#      10 from zipline.assets._assets import Equity
# ---> 11 from zipline.pipeline.loaders.blaze import BlazeLoader, from_blaze
#      12 from zipline.utils.run_algo import load_extensions
#      13
#
# ~/hca/zipline/zipline/pipeline/loaders/blaze/__init__.py in <module>
# ----> 1 from .core import (
#       2     BlazeLoader,
#       3     NoMetaDataWarning,
#       4     from_blaze,
#       5     global_loader,
#
# ~/hca/zipline/zipline/pipeline/loaders/blaze/core.py in <module>
#     145 from weakref import WeakKeyDictionary
#     146
# --> 147 import blaze as bz
#     148 from datashape import (
#     149     Date,
#
# ~/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/blaze/__init__.py in <module>
#       7
#       8 from pandas import DataFrame
# ----> 9 from odo import odo, convert, append, drop, resource
#      10 from odo.backends.csv import CSV
#      11 from odo.backends.json import JSON, JSONLines
#
# ~/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/odo/__init__.py in <module>
#      63     from .backends.url import URL
#      64 with ignoring(ImportError):
# ---> 65     from .backends.dask import dask
#      66
#      67
#
# ~/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/odo/backends/dask.py in <module>
#      11 import dask.bag as db
#      12 from dask.compatibility import long
# ---> 13 import dask.dataframe as dd
#      14
#      15 from odo import append, chunks, convert, discover, TextFile
#
# ~/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/dask/dataframe/__init__.py in <module>
#       1 from __future__ import print_function, division, absolute_import
#       2
# ----> 3 from .core import (DataFrame, Series, Index, _Frame, map_partitions,
#       4                    repartition, to_delayed)
#       5 from .io import (from_array, from_pandas, from_bcolz,
#
# ~/anaconda3/envs/env_hca_live/lib/python3.6/site-packages/dask/dataframe/core.py in <module>
#      36 no_default = '__no_default__'
#      37
# ---> 38 pd.computation.expressions.set_use_numexpr(False)
#      39
#      40
#
# AttributeError: module 'pandas' has no attribute 'computation'

# %%
# Example of use in a Custom Factor

class MyFactor(CustomFactor):
    inputs = [Factory['sample'].value]
    window_length = 10
    
    def compute(self, today, assets, out, factory):
        out[:] = factory[-1]

# %%
assets = get_symbols(['A', 'AAL'], as_of_date=None)

# %%
assets
# Out:
# [Equity(0 [A]), Equity(2 [AAL])]

# %%
p = Pipeline(
    columns={
        'col_A': Factory['sample'].value.latest,
        'col_B': MyFactor()
    },
    screen=StaticAssets(assets)
)

# %%
df = run_pipeline(
    p,
    pd.Timestamp('2016-01-05', tz='utc'),
    pd.Timestamp('2018-01-04', tz='utc')
)

# %%
df.head()
# Out:
#                                               col_A     col_B
# 2016-01-05 00:00:00+00:00 Equity(0 [A])    0.543405  0.543405
#                           Equity(2 [AAL])  0.424518  0.424518
# 2016-01-06 00:00:00+00:00 Equity(0 [A])    0.543405  0.543405
#                           Equity(2 [AAL])  0.424518  0.424518
# 2016-01-07 00:00:00+00:00 Equity(0 [A])    0.543405  0.543405
